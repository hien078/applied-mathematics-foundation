# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hien078/applied-mathematics-foundation/blob/master/information_theory/kl_divergence.ipynb)
#
# # KL Divergence — Numerical Verification
#
# **Goal.** Verify non-negativity, asymmetry, and the cross-entropy decomposition.

# %%
import random

import matplotlib.pyplot as plt
import numpy as np

# %load_ext autoreload
# %autoreload 2

SEED = 42
random.seed(SEED)
rng = np.random.default_rng(SEED)

# %% [markdown]
# ## WHAT and HOW
#
# For positive discrete probabilities, $D_{\mathrm{KL}}(p\lVert q)=\sum_kp_k\log(p_k/q_k)$.

# %%
def kl(p, q):
    return float(np.sum(p * np.log(p / q)))

p = np.array([0.7, 0.2, 0.1])
q = np.array([0.4, 0.4, 0.2])
entropy = -np.sum(p * np.log(p))
cross_entropy = -np.sum(p * np.log(q))
assert kl(p, q) >= -1e-12
assert not np.isclose(kl(p, q), kl(q, p))
assert np.isclose(cross_entropy, entropy + kl(p, q), atol=1e-12)
print(f"KL(p || q) = {kl(p, q):.6f}")
# Out:
# KL(p || q) = 0.183787

# %% [markdown]
# ## CONNECTIONS
#
# KL divergence appears in t-SNE, variational inference, knowledge distillation, and likelihood comparison. It is not a distance metric.
